# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Admin\Downloads\Heart.csv")
data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 3        0      3.5      3  0.0      normal   No
# 4        0      1.4      1  0.0      normal   No
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No
#
# [303 rows x 15 columns]

# %%
df=data.iloc[:,1:]
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# 1        1.5      2  3.0      normal  Yes
# 2        2.6      2  2.0  reversable  Yes
# 3        3.5      3  0.0      normal   No
# 4        1.4      1  0.0      normal   No
# ..       ...    ...  ...         ...  ...
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  NaN      normal   No
#
# [303 rows x 14 columns]

# %%
dt=df.dtypes
dt
# Out:
# Age            int64
# Sex            int64
# ChestPain     object
# RestBP         int64
# Chol           int64
# Fbs            int64
# RestECG        int64
# MaxHR          int64
# ExAng          int64
# Oldpeak      float64
# Slope          int64
# Ca           float64
# Thal          object
# AHD           object
# dtype: object

# %%
avg=df['Age'].mean()
avg
# Out:
# 54.43894389438944

# %%
miss=df.isnull()
miss
# Out:
#        Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  MaxHR  ExAng  \
# 0    False  False      False   False  False  False    False  False  False
# 1    False  False      False   False  False  False    False  False  False
# 2    False  False      False   False  False  False    False  False  False
# 3    False  False      False   False  False  False    False  False  False
# 4    False  False      False   False  False  False    False  False  False
# ..     ...    ...        ...     ...    ...    ...      ...    ...    ...
# 298  False  False      False   False  False  False    False  False  False
# 299  False  False      False   False  False  False    False  False  False
# 300  False  False      False   False  False  False    False  False  False
# 301  False  False      False   False  False  False    False  False  False
# 302  False  False      False   False  False  False    False  False  False
#
#      Oldpeak  Slope     Ca   Thal    AHD
# 0      False  False  False  False  False
# 1      False  False  False  False  False
# 2      False  False  False  False  False
# 3      False  False  False  False  False
# 4      False  False  False  False  False
# ..       ...    ...    ...    ...    ...
# 298    False  False  False  False  False
# 299    False  False  False  False  False
# 300    False  False  False  False  False
# 301    False  False  False  False  False
# 302    False  False   True  False  False
#
# [303 rows x 14 columns]

# %%
missing=df.isnull().sum()
missing
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
shape=df.shape
shape
# Out:
# (303, 14)

# %%
df1=df[df==0]
df1.count()
# Out:
# Age            0
# Sex           97
# ChestPain      0
# RestBP         0
# Chol           0
# Fbs          258
# RestECG      151
# MaxHR          0
# ExAng        204
# Oldpeak       99
# Slope          0
# Ca           176
# Thal           0
# AHD            0
# dtype: int64

# %%
data1=df[['Age','Sex','ChestPain','RestBP',"Chol"]]
data1
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 0     63    1       typical     145   233
# 1     67    1  asymptomatic     160   286
# 2     67    1  asymptomatic     120   229
# 3     37    1    nonanginal     130   250
# 4     41    0    nontypical     130   204
# ..   ...  ...           ...     ...   ...
# 298   45    1       typical     110   264
# 299   68    1  asymptomatic     144   193
# 300   57    1  asymptomatic     130   131
# 301   57    0    nontypical     130   236
# 302   38    1    nonanginal     138   175
#
# [303 rows x 5 columns]

# %%
div75=df.sample(frac=0.75)
div25=df.drop(div75.index)
div75
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 53    44    1    nontypical     130   219    0        2    188      0
# 159   68    1    nonanginal     118   277    0        0    151      0
# 244   60    0    nonanginal     120   178    1        0     96      0
# 190   50    1    nonanginal     129   196    0        0    163      0
# 103   71    0    nonanginal     110   265    1        2    130      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 284   61    1  asymptomatic     148   203    0        0    161      0
# 248   52    1  asymptomatic     125   212    0        0    168      0
# 82    39    1    nonanginal     140   321    0        2    182      0
# 122   51    1    nonanginal     100   222    0        0    143      1
# 110   61    0  asymptomatic     145   307    0        2    146      1
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 53       0.0      1  0.0      normal   No
# 159      1.0      1  1.0  reversable   No
# 244      0.0      1  0.0      normal   No
# 190      0.0      1  0.0      normal   No
# 103      0.0      1  1.0      normal   No
# ..       ...    ...  ...         ...  ...
# 284      0.0      1  1.0  reversable  Yes
# 248      1.0      1  2.0  reversable  Yes
# 82       0.0      1  0.0      normal   No
# 122      1.2      2  0.0      normal   No
# 110      1.0      2  0.0  reversable  Yes
#
# [227 rows x 14 columns]

# %%
div25
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 8     63    1  asymptomatic     130   254    0        2    147      0
# 9     53    1  asymptomatic     140   203    1        2    155      1
# 13    44    1    nontypical     120   263    0        0    173      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 289   56    1    nontypical     120   240    0        0    169      0
# 293   63    1  asymptomatic     140   187    0        2    144      1
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# 1        1.5      2  3.0      normal  Yes
# 8        1.4      2  1.0  reversable  Yes
# 9        3.1      3  0.0  reversable  Yes
# 13       0.0      1  0.0  reversable   No
# ..       ...    ...  ...         ...  ...
# 289      0.0      3  0.0      normal   No
# 293      4.0      1  2.0  reversable  Yes
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
#
# [76 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,:5]
y=df.iloc[:,13]
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.75,test_size=0.25)
X_train
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 175   57    1  asymptomatic     152   274
# 65    60    1  asymptomatic     145   282
# 112   52    1       typical     118   186
# 66    60    1    nonanginal     140   185
# 93    44    0    nonanginal     108   141
# ..   ...  ...           ...     ...   ...
# 290   67    1    nonanginal     152   212
# 260   44    0    nonanginal     118   242
# 261   58    0    nontypical     136   319
# 144   58    1    nonanginal     105   240
# 139   51    1    nonanginal     125   245
#
# [227 rows x 5 columns]

# %%
Y_train
# Out:
# 175    Yes
# 65     Yes
# 112     No
# 66     Yes
# 93      No
#       ...
# 290    Yes
# 260     No
# 261    Yes
# 144     No
# 139     No
# Name: AHD, Length: 227, dtype: object

# %%
X_test
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 101   34    1       typical     118   182
# 35    42    1  asymptomatic     140   226
# 134   43    0    nonanginal     122   213
# 57    41    1  asymptomatic     110   172
# 25    50    0    nonanginal     120   219
# ..   ...  ...           ...     ...   ...
# 145   47    1    nonanginal     108   243
# 92    62    1    nonanginal     130   231
# 103   71    0    nonanginal     110   265
# 177   56    1  asymptomatic     132   184
# 190   50    1    nonanginal     129   196
#
# [76 rows x 5 columns]

# %%
Y_test
# Out:
# 101     No
# 35      No
# 134     No
# 57     Yes
# 25      No
#       ...
# 145    Yes
# 92      No
# 103     No
# 177    Yes
# 190     No
# Name: AHD, Length: 76, dtype: object

# %%
data=data.replace({'Yes':0,'No':1})
data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed    1
# 1        1      1.5      2  3.0      normal    0
# 2        1      2.6      2  2.0  reversable    0
# 3        0      3.5      3  0.0      normal    1
# 4        0      1.4      1  0.0      normal    1
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable    0
# 299      0      3.4      2  2.0  reversable    0
# 300      1      1.2      2  1.0  reversable    0
# 301      0      0.0      2  1.0      normal    0
# 302      0      0.0      1  NaN      normal    1
#
# [303 rows x 15 columns]

# %%
dict={'Yes':0,'No':1}
update=data['AHD'].map(dict)
data['AHD']=update
data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed  NaN
# 1        1      1.5      2  3.0      normal  NaN
# 2        1      2.6      2  2.0  reversable  NaN
# 3        0      3.5      3  0.0      normal  NaN
# 4        0      1.4      1  0.0      normal  NaN
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  NaN
# 299      0      3.4      2  2.0  reversable  NaN
# 300      1      1.2      2  1.0  reversable  NaN
# 301      0      0.0      2  1.0      normal  NaN
# 302      0      0.0      1  NaN      normal  NaN
#
# [303 rows x 15 columns]
